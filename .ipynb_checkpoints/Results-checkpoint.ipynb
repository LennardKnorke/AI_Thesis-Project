# %% [markdown]
# ## Results

# %%
import os
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tiny_hanabi.game.assemblers import get_game, normalize_payoffs
from tiny_hanabi.game.payoff_matrices import OPTIMAL_RETURNS, GameNames
from typing import Dict, Any, List, Optional

sns.set_theme(style="whitegrid", palette="viridis")
plt.rcParams['figure.figsize'] = [12, 7] # Default figure size

# --- CONFIGURATION ---
RESULTS_BASE_DIR = "Results"
HYPERSEARCH_BASE_DIR = "HyperSearchResults"
GAMES = ["A", "B", "C", "D", "E", "F"]

# List of all baseline agent names (ensure these match your Experiment.name in config.py)
BASELINE_AGENT_NAMES = [
    "DTDE QSarsa",
    "CTDE VDN",
    "DTDE BI",
    "CTDE BI"
]

TOM_AGENT_NAME = "DTDE ToMBI"

# %%
def load_baseline_self_play_results() -> pd.DataFrame:
    """
    Loads the final average rewards of baseline agents playing against themselves
    from their respective 'final_results.csv' files.
    """
    all_self_play_data = []
    
    print("Loading baseline self-play results...")
    for agent_name in BASELINE_AGENT_NAMES:
        folder_name = agent_name.replace(" ", "_")
        results_path = os.path.join(RESULTS_BASE_DIR, folder_name, "final_results.csv")
        
        if not os.path.exists(results_path):
            print(f"Warning: Self-play results not found for {agent_name} at {results_path}")
            continue
            
        try:
            df = pd.read_csv(results_path)
            
            # For self-play, we're interested in the final reward after full training.
            # 'final_results.csv' typically has reward_GameX columns.
            # We take the mean of the last 10 episodes for robustness.
            # For BI, it's just the final iteration.
            
            for game in GAMES:
                reward_col = f"reward_{game}"
                if reward_col in df.columns:
                    # Take the last value (for BI) or average of last few (for MF)
                    # Assuming for now it's just the final value after training
                    final_avg_reward = df[reward_col].iloc[-1]
                    
                    all_self_play_data.append({
                        "game": game,
                        "focal_agent_type": agent_name,
                        "partner_agent_type": agent_name,
                        "scenario_type": "Baseline vs. Self-Play",
                        "avg_reward": final_avg_reward
                    })
        except Exception as e:
            print(f"  Error loading self-play results for {agent_name}: {e}")
            
    print(f"Loaded {len(all_self_play_data)} self-play results.")
    return pd.DataFrame(all_self_play_data)

# %%
def load_tom_comparison_results() -> pd.DataFrame:
    """
    Loads the comparison results of the ToM agent playing against baselines
    from 'ToM_Agent_Comparison_Results.csv'.
    """
    tom_results_path = os.path.join(RESULTS_BASE_DIR, TOM_AGENT_NAME.replace(" ", "_"), "ToM_Agent_Comparison_Results.csv")
    
    if not os.path.exists(tom_results_path):
        print(f"ToM agent comparison results not found at {tom_results_path}. Please run train_test_tom.py first.")
        return pd.DataFrame()
        
    try:
        df = pd.read_csv(tom_results_path)
        print(f"Loaded {len(df)} ToM agent comparison results.")
        return df
    except Exception as e:
        print(f"Error loading ToM agent comparison results: {e}")
        return pd.DataFrame()

# You might want a function to load optimal returns for plotting reference
def get_optimal_returns_df() -> pd.DataFrame:
    """Returns a DataFrame of optimal returns per game."""
    optimal_data = [{"game": game, "optimal_reward": val} for game, val in OPTIMAL_RETURNS.items()]
    return pd.DataFrame(optimal_data)

# %%
df_self_play = load_baseline_self_play_results()
df_tom_comparison = load_tom_comparison_results()
df_optimal = get_optimal_returns_df()

# --- Merge and Structure Data for Plotting ---
plotting_data = []

# 1. Add Self-Play Baselines
if not df_self_play.empty:
    for _, row in df_self_play.iterrows():
        plotting_data.append({
            "Game": row["game"],
            "Partner Agent Type": row["partner_agent_type"],
            "Focal Agent Type": row["focal_agent_type"], # For self-play, partner == focal
            "Scenario": row["scenario_type"],
            "Average Reward": row["avg_reward"]
        })

if not df_tom_comparison.empty:
    for _, row in df_tom_comparison.iterrows():
        # Scenario 1: ToM is P0
        if row["tom_role"] == "P0":
            plotting_data.append({
                "Game": row["game"],
                "Partner Agent Type": row["partner_agent_type"],
                "Focal Agent Type": TOM_AGENT_NAME,
                "Scenario": f"{TOM_AGENT_NAME} (P0) vs. {row['partner_agent_type']} (P1)",
                "Average Reward": row["avg_reward"]
            })
        # Scenario 2: ToM is P1
        elif row["tom_role"] == "P1":
            plotting_data.append({
                "Game": row["game"],
                "Partner Agent Type": row["partner_agent_type"],
                "Focal Agent Type": TOM_AGENT_NAME,
                "Scenario": f"{row['partner_agent_type']} (P0) vs. {TOM_AGENT_NAME} (P1)",
                "Average Reward": row["avg_reward"]
            })

df_plot = pd.DataFrame(plotting_data)

# Merge with optimal returns for plotting reference
df_plot = pd.merge(df_plot, df_optimal, on="game", how="left")

print(f"\nFinal plotting DataFrame created with {len(df_plot)} entries.")
print("DataFrame Head:")
print(df_plot.head())
# Out:
# Loading baseline self-play results...
# Loaded 24 self-play results.
# ToM agent comparison results not found at Results\DTDE_ToMBI\ToM_Agent_Comparison_Results.csv. Please run train_test_tom.py first.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_62092\2908172378.py in ?()
#      39
#      40 df_plot = pd.DataFrame(plotting_data)
#      41
#      42 # Merge with optimal returns for plotting reference
# ---> 43 df_plot = pd.merge(df_plot, df_optimal, on="game", how="left")
#      44
#      45 print(f"\nFinal plotting DataFrame created with {len(df_plot)} entries.")
#      46 print("DataFrame Head:")
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
# ...

# %%
if df_plot.empty:
    print("No data available to generate plots.")
else:
    print("\nGenerating performance comparison plots per game...")
    
    for game in GAMES:
        fig, ax = plt.subplots(figsize=(14, 8))
        
        # Filter data for the current game
        game_data = df_plot[df_plot["Game"] == game].copy()
        
        if game_data.empty:
            print(f"  No data for Game {game}. Skipping plot.")
            plt.close(fig) # Close empty figure
            continue

        # Sort partners for consistent plotting order
        game_data["Partner Agent Type"] = pd.Categorical(
            game_data["Partner Agent Type"], 
            categories=BASELINE_AGENT_NAMES, 
            ordered=True
        )
        game_data = game_data.sort_values("Partner Agent Type")


        # Define custom hue order for legend clarity: ToM P0, ToM P1, Baseline Self-Play
        hue_order = [
            f"{TOM_AGENT_NAME} (P0) vs. {partner} (P1)" for partner in BASELINE_AGENT_NAMES
        ] + [
            f"{partner} (P0) vs. {TOM_AGENT_NAME} (P1)" for partner in BASELINE_AGENT_NAMES
        ] + [
            f"{partner} vs. Self-Play" for partner in BASELINE_AGENT_NAMES
        ]
        
        # Adjust Scenario names for self-play to fit the pattern
        game_data['Scenario'] = game_data.apply(
            lambda row: f"{row['Partner Agent Type']} vs. Self-Play" 
                        if "Self-Play" in row['Scenario'] 
                        else row['Scenario'], 
            axis=1
        )
        
        # Make sure hue_order only contains scenarios actually present in the data
        actual_scenarios = game_data['Scenario'].unique()
        final_hue_order = [s for s in hue_order if s in actual_scenarios]


        # Create the scatter plot
        sns.scatterplot(
            data=game_data,
            x="Partner Agent Type",
            y="Average Reward",
            hue="Scenario", # This now groups ToM P0, ToM P1, and Baseline Self-Play
            hue_order=final_hue_order,
            style="Focal Agent Type", # Use style to differentiate between ToM and Baselines generally
            s=200, # Point size
            ax=ax,
            zorder=3 # Ensure points are above gridlines
        )

        # Plot Optimal Return line
        optimal_reward = game_data["optimal_reward"].iloc[0]
        ax.axhline(y=optimal_reward, color='green', linestyle='--', linewidth=2, label=f"Optimal Reward: {optimal_reward:.2f}", zorder=1)

        ax.set_title(f"Performance Comparison for Game {game}", fontsize=18)
        ax.set_xlabel("Partner Agent Type", fontsize=14)
        ax.set_ylabel("Average Reward", fontsize=14)
        ax.tick_params(axis='x', rotation=45, ha='right') # Rotate x-axis labels
        ax.set_ylim(bottom=0) # Ensure y-axis starts at 0

        # Improve legend placement
        ax.legend(title="Scenario", bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
        plt.tight_layout()
        plt.show()

print("\nPlots generated. Proceed to 'Further Analysis' cell for discussion.")
# Out:
# Generating performance comparison plots per game...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'optimal_reward'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# #### Baselines Overview

# %%
baselines_df = {}
baselines_params = {}
for agent in AGENTS:
    df, params = load_df(agent)
    baselines_df[agent] = df
    baselines_params[agent] = params
    print(agent)
    print(params)
    print("\n\n")
# Out:
# Independent_RL_Agent
# {'lr': 0.1, 'gamma': 1.0, 'batch_size': 32, 'updates_per_train': 5}
#
#
#
# Independent_VI_Agent
# {'convergence_threshold': 1e-05, 'max_iterations': 20.0, 'partner_epsilon': 1.0}
#
#
#
# VDN_RL_Agents
# {'lr': 0.001, 'gamma': 0.99, 'batch_size': 64, 'buffer_size': 500, 'updates_per_train': 1, 'epsilon_start': 1.0, 'epsilon_min': 0.1, 'epsilon_decay': 0.999}
#
#
#
# VDN_VI_Agents
# {'lr': 0.001, 'gamma': 0.99, 'batch_size': 64, 'buffer_size': 500, 'updates_per_train': 1.0, 'epsilon_start': 1.0, 'epsilon_min': 0.1, 'epsilon_decay': 0.999}
